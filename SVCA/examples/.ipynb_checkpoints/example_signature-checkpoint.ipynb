# %%
# importing packages
from svca.util_functions import util_functions
from svca.run import run_indiv
import os

# %%
# defining image directory, output directory 
image_dir = 'data/IMC_example/Cy1x7/'
res_root = '/tmp/svca_example/'
plot_dir = '/tmp/svca_plot_example'

# creating output directories
res_dir = util_functions.make_dir(res_root+'/results/')  # this function prevents overwriting directories by incrementing the name if the directory already exists
plot_dir = util_functions.make_dir(plot_dir)

# %%
# running SVCA on the first 3 proteins.
# all results are saved in res_dir
for prot in range(5):
    run_indiv.run(image_dir, prot, res_dir);
# Out:
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 1.72 s
# Log Marginal Likelihood: 142.4179813.
# Gradient norm: 0.0034830.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 0.66 s
# Log Marginal Likelihood: 142.0469322.
# Gradient norm: 0.0053411.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 0.82 s
# Log Marginal Likelihood: 136.7679529.
# Gradient norm: 0.0016664.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 0.54 s
# Log Marginal Likelihood: 132.1181060.
# Gradient norm: 0.0018962.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 1.15 s
# Log Marginal Likelihood: 126.3538389.
# Gradient norm: 0.0031409.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 0.42 s
# Log Marginal Likelihood: 125.3435756.
# Gradient norm: 0.0011014.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 0.53 s
# Log Marginal Likelihood: 124.6631103.
# Gradient norm: 0.0000087.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 0.72 s
# Log Marginal Likelihood: 124.9587655.
# Gradient norm: 0.0057128.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 0.71 s
# Log Marginal Likelihood: 125.7799804.
# Gradient norm: 0.0000077.
# Marginal likelihood optimization.
# ('Converged:', True)
# Time elapsed: 0.97 s
# Log Marginal Likelihood: 129.0083727.
# Gradient norm: 0.0044017.

# %%
# plot the variance signatures to visualise the results
# %load_ext rpy2.ipython
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-3a04c4410b55> in <module>()
#       1 # plot the variance signatures to visualise the results
# ----> 2 get_ipython().magic(u'load_ext rpy2.ipython')
#       3
#
# /Users/damienarnol1/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2156         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2157         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2158         return self.run_line_magic(magic_name, magic_arg_s)
#    2159
#    2160     #-------------------------------------------------------------------------
#
# /Users/damienarnol1/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2077                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2078             with self.builtin_trap:
# -> 2079                 result = fn(*args,**kwargs)
#    2080             return result
#    2081
#
# <decorator-gen-62> in load_ext(self, module_str)
#
# /Users/damienarnol1/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /Users/damienarnol1/anaconda/lib/python2.7/site-packages/IPython/core/magics/extension.pyc in load_ext(self, module_str)
#      35         if not module_str:
#      36             raise UsageError('Missing module name.')
# ---> 37         res = self.shell.extension_manager.load_extension(module_str)
#      38
#      39         if res == 'already loaded':
#
# /Users/damienarnol1/anaconda/lib/python2.7/site-packages/IPython/core/extensions.pyc in load_extension(self, module_str)
#      81             if module_str not in sys.modules:
#      82                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 83                     __import__(module_str)
#      84             mod = sys.modules[module_str]
#      85             if self._call_load_ipython_extension(mod):
#
# /Users/damienarnol1/anaconda/lib/python2.7/site-packages/rpy2/ipython/__init__.py in <module>()
# ----> 1 from .rmagic import load_ipython_extension
#
# /Users/damienarnol1/anaconda/lib/python2.7/site-packages/rpy2/ipython/rmagic.py in <module>()
#      50 # numpy and rpy2 imports
#      51
# ---> 52 import rpy2.rinterface as ri
#      53 import rpy2.robjects as ro
#      54 import rpy2.robjects.packages as rpacks
#
# /Users/damienarnol1/anaconda/lib/python2.7/site-packages/rpy2/rinterface/__init__.py in <module>()
#      90 del(os)
#      91
# ---> 92 from rpy2.rinterface._rinterface import (baseenv,
#      93                                          emptyenv,
#      94                                          endr,
#
# ImportError: dlopen(/Users/damienarnol1/anaconda/lib/python2.7/site-packages/rpy2/rinterface/_rinterface.so, 2): Library not loaded: @rpath/libiconv.2.dylib
#   Referenced from: /Users/damienarnol1/anaconda/lib/python2.7/site-packages/rpy2/rinterface/_rinterface.so
#   Reason: Incompatible library version: _rinterface.so requires version 9.0.0 or later, but libiconv.2.dylib provides version 8.0.0

# %%
# %%R -i res_root
# source('../svca/plot_scripts/visu_signatures_functions.R')
# all_res_merged = read_all_signatures(res_root)
# plot_sig_bars(all_res_merged)
# Out:
# ERROR:root:Cell magic `%%R` not found.
